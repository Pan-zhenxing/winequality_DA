# %% [markdown]
# # 影响红酒品质因素分析
#
# ## 项目背景
#
#     学习数据分析知识已经有三个多月，好在上大学时自学python打下一些基础，到目前为止也算学了不少内容，接下来打算慢慢开始找工作。在此之前，通过实战一些项目把学到的知识复习回顾一遍，通过实战提高应用能力，多多练习以增加熟练度。本项目旨在重点练习python数据分析相关知识，主要包括numpy、padnas、和matplotlib这几个常用库。
#
# ## 项目简介
#
#     这个数据集共有1599个样本，11个红酒的理化性质，以及红酒的品质（评分从0到10）。这里主要目的在于展示进行数据分析的常见python包的调用，以及数据可视化。分析各理化性质对品质的影响，主要内容分为：单变量，双变量，和多变量分析。
# | 内容        | 字段                |
# |:----------  |:------              |
# |非挥发性酸   |fixed acidity        |
# |挥发性酸     |volatile acidity     |
# |柠檬酸       |citric acid          |
# |残糖         |residual sugar       |
# |氯化物       |chlorides            |
# |游离二氧化硫 |free sulfur dioxide  |
# |总二氧化硫量 |total sulfur dioxide |
# |密度         |density              |
# |酸碱度       |pH                   |
# |硫酸盐       |sulphates            |
# |酒精度       |alcohol              |
# |品质         |quality              |
#
# ## 数据探索
#
#     在这个项目中，数据是从阿里天池网站上获取的CSV数据，数据本身相对完整，不需要再进行数据采集。CSV是一个通用性非常强的文本文件格式，许多软件都可以处理CSV文件，比如大名鼎鼎的Excel。但是本项目我打算采用Python作为分析工具对数据进行分析和处理。

# %% [markdown]
# 首先应当导入本项目中可能用到的库，比如numpy，pandas，matplotlib, seaborn等，代码如下：

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

color = sns.color_palette()  #颜色设置

pd.set_option('precision',3) #设置数据精度

# %% [markdown]
# 读取数据

# %%
df = pd.read_csv(r'D:\Backup\桌面\winequality-red.csv',sep = ';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0    0.998  3.51       0.56
# 1                 25.0                  67.0    0.997  3.20       0.68
# 2                 15.0                  54.0    0.997  3.26       0.65
# 3                 17.0                  60.0    0.998  3.16       0.58
# 4                 11.0                  34.0    0.998  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## 单变量分析

# %%
# 查看数据统计概况
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count       1599.000          1599.000     1599.000        1599.000
# mean           8.320             0.528        0.271           2.539
# std            1.741             0.179        0.195           1.410
# min            4.600             0.120        0.000           0.900
# 25%            7.100             0.390        0.090           1.900
# 50%            7.900             0.520        0.260           2.200
# 75%            9.200             0.640        0.420           2.600
# max           15.900             1.580        1.000          15.500
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   1599.000             1599.000              1599.000  1599.000
# mean       0.087               15.875                46.468     0.997
# std        0.047               10.460                32.895     0.002
# min        0.012                1.000                 6.000     0.990
# 25%        0.070                7.000                22.000     0.996
# 50%        0.079               14.000                38.000     0.997
# 75%        0.090               21.000                62.000     0.998
# max        0.611               72.000               289.000     1.004
#
#              pH  sulphates   alcohol   quality
# count  1599.000   1599.000  1599.000  1599.000
# mean      3.311      0.658    10.423     5.636
# std       0.154      0.170     1.066     0.808
# min       2.740      0.330     8.400     3.000
# 25%       3.210      0.550     9.500     5.000
# 50%       3.310      0.620    10.200     6.000
# 75%       3.400      0.730    11.100     6.000
# max       4.010      2.000    14.900     8.000

# %%
# 设置plot样式
plt.style.use('ggplot')

# %%
colnm = df.columns.tolist() #将数据源以columns形式转化为list

fig = plt.figure(figsize = (10, 6)) #设置绘图尺寸

for i in range(12):        #因为是单变量的分析，使用for分别绘制
    plt.subplot(2, 6, i+1)
    sns.boxplot(df[colnm[i]], orient='v',width = 0.5, color = color[0])
    plt.ylabel(colnm[i], fontsize = 12)
    
plt.tight_layout()
print('\nFigure 1: 单变量箱体图')
# Out:
# Figure 1: 单变量箱体图

# %%
colnm = df.columns.tolist()
plt.figure(figsize = (10, 8))

for i in range(12):
    plt.subplot(4, 3, i+1)
    df[colnm[i]].hist(bins = 100, color = color[0])
    plt.xlabel(colnm[i], fontsize = 12)
    plt.ylabel('Frequency')
plt.tight_layout()
print('\nFigure 2:单变量柱形图')
# Out:
# Figure 2:单变量柱形图

# %% [markdown]
# ## 品质
# 这个数据集的目的是研究红酒品质和理化性质之间的关系。品质的评价范围是0-10，这个数据集中范围是3到8，有超过50%的红酒品质是5或6。

# %% [markdown]
# ## 酸度相关的特征
#
# 这个数据集有7个酸度相关的特征：fixed acidity, volatile acidity, citric acid, free sulfur dioxide, total sulfur dioxide, sulphates, pH。前6个特征都与红酒的pH的相关。pH是在对数的尺度，下面对前6个特征取对数然后作histogram。另外，pH值主要是与fixed acidity有关，fixed acidity比volatile acidity和citric acid高1到2个数量级(Figure 4)，比free sulfur dioxide, total sulfur dioxide, sulphates高3个数量级。一个新特征total acid来自于前三个特征的和。

# %%
acidityFeat = ['fixed acidity', 'volatile acidity', 'citric acid',
               'free sulfur dioxide', 'total sulfur dioxide', 'sulphates']
# 为下一步限定截取数据，创建list

plt.figure(figsize = (10, 4))

for i in range(6):
    ax = plt.subplot(2, 3, i+1)
    v = np.log10(np.clip(df[acidityFeat[i]].values, a_min = 0.001, a_max = None))
    plt.hist(v, bins = 50, color = color[1])
    plt.xlabel('log(' + acidityFeat[i] + ')', fontsize = 12)
    plt.ylabel('Frequency')
plt.tight_layout()
print('\nFigure 3:log10酸度特征')
# Out:
# Figure 3:log10酸度特征

# %%
plt.figure(figsize=(6,3))

bins = 10**(np.linspace(-2, 2))
plt.hist(df['fixed acidity'], bins = bins, edgecolor = 'k', label = 'Fixed Acidity')
plt.hist(df['volatile acidity'], bins = bins, edgecolor = 'k', label = 'Volatile Acidity')
plt.hist(df['citric acid'], bins = bins, edgecolor = 'k', alpha = 0.7, label = 'Citric Acid')
plt.xscale('log')
plt.xlabel('Acid Concentration (g/dm^3)')
plt.ylabel('Frequency')
plt.title('Histogram of Acid Concentration')
plt.legend()
plt.tight_layout()

print('Figure 4')
# Out:
# Figure 4

# %%
# 总酸度
df['total acid'] = df['fixed acidity']+ df['volatile acidity'] + df['citric acid']

# %%
plt.figure(figsize=(8, 3))

plt.subplot(121)
plt.hist(df['total acid'], bins = 50, color = color[1])
plt.xlabel('total acid')
plt.ylabel('Frequency')
plt.subplot(122)
plt.hist(np.log(df['total acid']), bins = 50, color = color[0])
plt.xlabel('log(total acid)')
plt.ylabel('Frequency')
plt.tight_layout()
print("Figure 5: 总酸度柱状图")
# Out:
# Figure 5: 总酸度柱状图

# %% [markdown]
# ## 甜度
# Residual sugar 与酒的甜度相关，通常用来区别各种红酒，干红（<=4 g/L), 半干（4-12 g/L）,半甜（12-45 g/L），和甜（>45 g/L)。 这个数据中，主要为干红，没有甜葡萄酒。

# %%
# Residual sugar 残糖
df['sweetness'] = pd.cut(df['residual sugar'], bins = [0, 4, 12, 45],
                        labels = ['dry','medium dry','semi-sweet'])

# %%
plt.figure(figsize = (5,3))
df['sweetness'].value_counts().plot(kind = 'bar', color = color[0])
plt.xticks(rotation = 0)
plt.xlabel('sweetness', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# # 双变量分析
#
# 红酒品质和理化特征的关系
# 下面是Figure 7和8 分别显示了红酒理化特征和品质之间的关系。
# 从图中可以看出的趋势规律如下几点：
#
# 1、品质好的酒有更高的柠檬酸，硫酸盐和酒精度数。硫酸盐(硫酸钙)的加入通常是调整酒的酸度的。其中酒精度数和品质的相关性最高。
#
# 2、品质好的酒有较低的挥发性酸类，密度和pH。
#
# 3、残糖，氯离子，二氧化硫似乎对酒的品质影响不大。

# %%
sns.set_style('ticks')
sns.set_context('notebook', font_scale = 1.1)

colnm = df.columns.tolist()[:11] + ['total acid']
plt.figure(figsize = (10, 8))

for i in range(12):
    plt.subplot(4, 3, i+1)
    sns.boxplot(x = 'quality', y= colnm[i], data = df, color = color[1], width = 0.6)
    plt.ylabel(colnm[i], fontsize = 12)
plt.tight_layout()

# %%
sns.set_style("dark")

plt.figure(figsize = (10,8))
colnm = df.columns.tolist()[:11] + ['total acid', 'quality']
mcorr = df[colnm].corr()
mask = np.zeros_like(mcorr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220, 10, as_cmap=True)
g = sns.heatmap(mcorr, mask=mask, cmap=cmap, square=True, annot=True, fmt='0.2f')
print("\nFigure 8: 成对相关图")
# Out:
# Figure 8: 成对相关图

# %% [markdown]
# ## 密度和酒精浓度
#
# 密度和酒精浓度是相关的，物理上，两者并不是线性关系。Figure 8展示了两者的关系。另外密度还与酒中其他物质的含量有关，但是关系很小。

# %%
# 风格设置
sns.set_style('ticks')
sns.set_context("notebook", font_scale= 1.4)

# 规格
plt.figure(figsize = (6,4))
sns.regplot(x='density', y = 'alcohol', data = df, scatter_kws = {'s':10}, color = color[0])
plt.xlim(0.989, 1.005)
plt.ylim(7,16)
print('Figure 9: 密度和酒精浓度')
# Out:
# Figure 9: 密度和酒精浓度

# %% [markdown]
# # 酸性物质含量和pH
#
# pH和非挥发性酸性物质有-0.683的相关性。因为非挥发性酸性物质的含量远远高于其他酸性物质，总酸性物质(total acidity)这个特征并没有太多意义。

# %%
acidity_related = ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 
                   'sulphates', 'total acid']

plt.figure(figsize = (10,6))

for i in range(5):
    plt.subplot(2,3,i+1)
    sns.regplot(x='pH', y = acidity_related[i], data = df, scatter_kws = {'s':10}, color = color[0])
plt.tight_layout()
print("Figure 10: 酸性物质含量和pH")
# Out:
# Figure 10: 酸性物质含量和pH

# %% [markdown]
# # 多变量分析
#
# 与品质相关性最高的三个特征是酒精浓度，挥发性酸度，和柠檬酸。下面图中显示的酒精浓度，挥发性酸和品质的关系。
# 酒精浓度，挥发性酸和品质
#
# 对于好酒（7，8）以及差酒（3，4），关系很明显。但是对于中等酒（5，6），酒精浓度的挥发性酸度有很大程度的交叉。

# %%
plt.style.use('ggplot')

sns.lmplot(x = 'alcohol', y = 'volatile acidity', hue = 'quality', 
           data = df, fit_reg = False, scatter_kws={'s':10}, height = 5)
print("Figure 11-1: 酒精、挥发性酸和质量的散点图")
# Out:
# Figure 11-1: 酒精、挥发性酸和质量的散点图

# %% [markdown]
# 通过上图发现，红酒的品质受挥发性酸影响较大，等级由3向8数据明显向右下方偏移。
# 由此可见红酒品质越好，内部成分所含的挥发性酸volatile acidity成分越低，在生产制造过程中，控制酒水中的挥发性酸含量低可能受到原料、制作工艺的因素影响，进而直接影响红酒品质。

# %%
sns.lmplot(x = 'alcohol', y = 'volatile acidity', col='quality', hue = 'quality', 
           data = df,fit_reg = False, height = 3,  aspect = 0.9, col_wrap=3,
           scatter_kws={'s':20})
print("Figure 11-2: 酒精、挥发性酸和质量的散点图")
# Out:
# Figure 11-2: 酒精、挥发性酸和质量的散点图

# %% [markdown]
#  通过对上图的观察可以清晰地发现，随着红酒品质的增加，相关数据 酒精、挥发性酸出现明显增加。整个品质分级也呈现出明显的正态分布情况。主要集中在品质5-7层级中。

# %% [markdown]
# ## pH，非挥发性酸，和柠檬酸
#
# pH和非挥发性的酸以及柠檬酸有相关性。整体趋势也很合理，即浓度越高，pH越低。

# %%
# 样式
sns.set_style('ticks')
sns.set_context("notebook", font_scale= 1.4)

plt.figure(figsize=(6,5))
cm = plt.cm.get_cmap('RdBu')
sc = plt.scatter(df['fixed acidity'], df['citric acid'], c=df['pH'], vmin=2.6, vmax=4, s=15, cmap=cm)
bar = plt.colorbar(sc)
bar.set_label('pH', rotation = 0)
plt.xlabel('fixed acidity')
plt.ylabel('citric acid')
plt.xlim(4,18)
plt.ylim(0,1)
print('Figure 12: pH，非挥发性酸，和柠檬酸')
# Out:
# Figure 12: pH，非挥发性酸，和柠檬酸

# %% [markdown]
# # 总结：
#
# 此项项目利用pandas库对原始数据进行处理和计算，并使用matplotlib库的pyplot模块和seaborn库对出具进行可视化操作。通过对数据的计算和对图形的观察，顺利找出影响红酒品质的主要影响因素。但需要说明的是，本项目中进行的分析仅仅是从数据本身展现出来的情况进行的，仅仅能表明数据之间的相关关系。在所有的分析结论中，数据之间的因果关系或者逻辑关系，仅仅是一种合理推测，并非严格的统计论证。
# 整体而言，红酒的品质主要与酒精浓度，挥发性酸，和柠檬酸有关。对于品质优于7，或者劣于4的酒，直观上是线性可分的。但是品质为5，6的酒很难线性区分。待以后有时间，还可以搭建一些机器学习的模型，通过数据训练，来预测数据不全的红酒品质情况。
